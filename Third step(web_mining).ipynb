# %% [markdown]
# Here we will unload data from thehttps://kudago.com/msk/places/ which will contain title and time of articles. This data is stored in their own links. So we will gather them and after go through them.

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import urllib3

from time import sleep
from random import randint

# %%
from selenium import webdriver
links =[]
pages = np.arange(1, 2,1)
http = urllib3.PoolManager()

# %% [markdown]
# Here we gather links on articles:

# %%
for page in pages:
    page = http.request('GET','https://kudago.com/msk/places/')
    soup = BeautifulSoup(page.data, 'html.parser')
    # parts of links are stored here:
    links_href = soup.find_all('a', class_='post-title-link', href =True)

    sleep(randint(2,10))
    
    for link1 in links_href:
        # Put it together:
        name1 = 'https://kudago.com'+link1.get('href')
        print(name1)
        links.append(name1)
# Out:
# https://kudago.com/online/place/attraktsion-metpet/
# https://kudago.com/msk/place/muzej-muzej-emotsij/
# https://kudago.com/msk/place/attraktsion-show-today/
# https://kudago.com/msk/place/centr-mars/
# https://kudago.com/msk/place/kubikulum-igra-kvest/
# https://kudago.com/msk/place/kinoteatr-lumiere-hall/
# https://kudago.com/msk/place/kinoteatr-sekret/
# https://kudago.com/msk/place/bar-bla-bla-bar-33331/
# https://kudago.com/msk/place/detskoe-mesto-umnyij-gorod-na-vdnh/
# https://kudago.com/msk/place/muzej-bunker-703/
# https://kudago.com/msk/place/proekt-progulka-v-temnote/
# https://kudago.com/msk/place/muzej-muzej-myortvyih-kukol/
# https://kudago.com/msk/place/ostankino/
# https://kudago.com/msk/place/attraktsion-stantsiya-2025/
# https://kudago.com/msk/place/bar-1929/
# https://kudago.com/msk/place/antikafe-antikafe-s-krolikami-zajkafe/
# https://kudago.com/msk/place/muzej-igrovyh-avtomatov/
# https://kudago.com/msk/place/antikafe-ezheminutka/
# https://kudago.com/msk/place/interesnoe-mesto-panorama-360/
# https://kudago.com/msk/place/strelkovyj-klub-labirint/
# https://kudago.com/msk/place/attraktsion-teleport360/
# https://kudago.com/msk/place/bassejn-chajka/
# https://kudago.com/msk/place/galerejnyj-centr-artefakt/
# https://kudago.com/msk/place/attraktsion-muzej-like-space/
# https://kudago.com/msk/place/attraktsion-warpoint-arena-33349/
# https://kudago.com/msk/place/kovorking-gravity/
# https://kudago.com/msk/place/bar-liberty/
# https://kudago.com/msk/place/attraktsion-hello-park/

# %%
len(links)
# Out:
# 28

# %% [markdown]
# And gather whatever you need using links we got before:

# %%
title =[]
moreinform =[]
for i in range(len(links)):
    i = http.request('GET', links[i])
    soup = BeautifulSoup(i.data, 'html.parser')
    man_h1 = soup.find_all('h1', class_="post-big-title")
    time_ = soup.find_all('time',class_="post-pubdate")
    
    sleep(randint(2,10))
    
    for link2 in man_h1:
        name2 = link2.get_text()
        title.append(name2)
    
    for link3 in time_:
        name3 = link3.get_text()
        moreinform.append(name3)

# %% [markdown]
# Here we are!

# %%
df = pd.DataFrame({'Title':title,'Time':moreinform})
df
# Out:
#                                                 Title                    Time
# 0   Сервис для поиска собак и кошек из приютов MetPet      24 июля 2020 12:12
# 1                                        Музей Эмоций  16 сентября 2019 21:58
# 2                   Развлекательный проект Show Today   3 сентября 2020 13:04
# 3                 Центр современного искусства «МАРС»   24 февраля 2021 16:45
# 4                            «Кубикулум» — игра-квест    1 августа 2019 11:47
# 5               Креативное пространство «Люмьер-Холл»   21 октября 2020 14:42
# 6                          Частный кинотеатр «Секрет»    21 января 2020 16:28
# 7                          Барный кластер Bla Bla Bar    9 октября 2020 14:55
# 8                      Павильон «Умный город» на ВДНХ     15 апреля 2019 9:33
# 9                       Арт-пространство «Бункер 703»   13 августа 2019 16:53
# 10          Cенсорная экспозиция «Прогулка в темноте»   3 сентября 2019 18:44
# 11                                Музей мёртвых кукол   12 февраля 2020 11:58
# 12                             Останкинская телебашня    30 ноября 2018 16:29
# 13          Развлекательно-игровой центр SТАНЦИЯ 2025    23 ноября 2020 16:57
# 14                                         Бар «1929»   14 февраля 2018 10:54
# 15                     Антикафе с кроликами «Зайкафе»    11 января 2020 15:41
# 16                  Музей советских игровых автоматов  28 сентября 2020 15:16
# 17                             Тайм-кафе «Ежеминутка»     25 марта 2019 10:52
# 18  Смотровая площадка PANORAMA360 в ММДЦ «Москва-...   5 сентября 2019 20:56
# 19                         Стрелковый клуб «Лабиринт»   6 сентября 2019 13:00
# 20                   Караоке лофт-студия TelePort360°   29 декабря 2020 18:42
# 21                 Бассейн под открытым небом «Чайка»   30 декабря 2019 12:46
# 22                        Галерейный центр «Артефакт»     6 января 2015 22:01
# 23                                   Музей Like Space   9 сентября 2020 17:38
# 24        Центр виртуальной реальности WARPOINT ARENA   20 октября 2020 13:46
# 25                                  Коворкинг Gravity     12 января 2021 9:41
# 26                                        Бар Liberty       7 июля 2019 17:06
# 27         Мультимедийный парк развлечений Hello Park     28 ноября 2019 9:50
